# %%
from arboVirose import arboVirose
from plot import plotGraficos
from geoPlot import geoRef
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

# %%
arbovirose = 'dengue'

# %%
arbo = arboVirose(arbovirose)

# %%
arbo.obterInfo()

# %%
linha = 'Município'
coluna = 'Ano da Notificação'
# 'Ano da Notificação', 'Ano do Óbito', 'Mês da Notificação', 'Sexo', 'Fx Etária SINAN'
periodo = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
# ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']

# %%
df = arbo.obterDf(linha, coluna, periodo)

# %%
geoR = geoRef(df)

# %%
plt.rcParams["figure.figsize"] = (15, 15)

# %%
geoR.plotCasos100milSturges('2020')
